# %%
before = 1

# %%
# `.set_index("bidder")` on a column with repeated values: the index is NOT unique.
bids.set_index("bidder")
# Out:
#         price
# bidder
# 3376      1.50
# 3376      2.25
# 3376      0.75
# 3788      3.00
# 3788      1.10
# 5272      0.40

# %%
after = 2
